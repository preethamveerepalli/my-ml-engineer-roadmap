# %%
print("I know how to print in python")
# Out:
# I know how to print in python

# %%
s=["I","Remember","about","Lists"]

# %%
print(f"printing a list: {s}")
# Out:
# printing a list: ['I', 'Remember', 'about', 'Lists']

# %%
print("printing a list: {s}")
# Out:
# printing a list: {s}

# %%
print(f"Progress: {24.68:.1f}%")
# Out:
# Progress: 24.7%

# %%
print("remembering the list opearations")
# Out:
# remembering the list opearations

# %%
for i, j in enumerate(s, 1):
    print(f"{i}. {j}")
# Out:
# 1. I
# 2. Remember
# 3. about
# 4. Lists

# %%
for i, j in enumerate(s):
    print(f"{i}. {j}")
# Out:
# 0. I
# 1. Remember
# 2. about
# 3. Lists

# %%
keyvaluepair = {
    "Key1": "I am ",
    "Key2": "learning",
    "Key3": "PyThon"
}

# %%
for key,value in keyvaluepair.items():  
    print(key, value)

for key in keyvaluepair.keys():  
    print(key)    
for value in keyvaluepair.values():  
    print(value)
# Out:
# Key1 I am
# Key2 learning
# Key3 PyThon
# Key1
# Key2
# Key3
# I am
# learning
# PyThon
